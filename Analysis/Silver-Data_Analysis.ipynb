# %%
display(spark.table("dbx_demo.silver.cleaned_crop_data").describe())

# %%
display(spark.table("dbx_demo.silver.cleaned_crop_data").groupBy("Crop").count())

# %%
display(spark.table("dbx_demo.silver.cleaned_crop_data").groupBy("State_Name").agg({"Production":"avg", "Area":"sum"}))

# %%
display(spark.table("dbx_demo.silver.cleaned_crop_data").groupBy("Crop_Year").agg({"Production":"sum", "Area":"sum"}))

# %%
display(spark.table("dbx_demo.silver.cleaned_crop_data").groupBy("Crop", "Crop_Year").agg({"Production":"avg"}))
