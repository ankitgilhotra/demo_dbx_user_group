# %%
spark.sql("CREATE CATALOG IF NOT EXISTS dbx_demo")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS dbx_demo.raw")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS dbx_demo.silver")

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS dbx_demo.gold_agg")
